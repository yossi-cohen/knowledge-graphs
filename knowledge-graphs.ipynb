# %% [markdown]
# #knowledge graphs

# %%
% cd '/content/drive/MyDrive/Colab Notebooks/knowledge-graphs'
# Out:
# /content/drive/MyDrive/Colab Notebooks/knowledge-graphs

# %%
# !git commit -am "ref"
# !git push

# %%
import numpy as np
#TODO
