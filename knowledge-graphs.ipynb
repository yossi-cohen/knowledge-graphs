# %% [markdown]
# #knowledge graphs

# %%
% cd '/content/drive/MyDrive/Colab Notebooks/knowledge-graphs'
# Out:
# /content/drive/MyDrive/Colab Notebooks/knowledge-graphs

# %%
import numpy as np
#TODO

# %%
# !git commit -am "ref"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@bc85aaee010d.(none)')
